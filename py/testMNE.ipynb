# %%
import mne
from mne_bids import (
    BIDSPath, # class
    find_matching_paths,
    get_entity_vals,
    make_report,
    print_dir_tree,
    read_raw_bids,
)

#import numpy as np
#a = (1,2)
BIDSPath

# eeg = mne.io.read_raw_brainvision('../../bids/sub-CCC/eeg/sub-CCC_task-actionDecoding_eeg.vhdr')

#eeg 
#BIDS
